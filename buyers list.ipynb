# %% [markdown]
# <a href="https://colab.research.google.com/github/nazRainer/data_visual/blob/main/buyers%20list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("Workshop Buyers Masterlist.csv")

# %%
df.head(70)
# Out:
#      No.                                    BUYER  ... Unnamed: 24 Unnamed: 25
# 0    1.0         Kota Ming Auto Repairers Sdn Bhd  ...         NaN         NaN
# 1    2.0        Sunshine Paint & Workshop Sdn Bhd  ...         NaN         NaN
# 2    3.0  Eng Lee Workshop & Spray Center Sdn Bhd  ...         NaN         NaN
# 3    4.0                   Super Hi-Shine Sdn Bhd  ...         NaN         NaN
# 4    5.0                        Atlas Auto Spares  ...         NaN         NaN
# ..   ...                                      ...  ...         ...         ...
# 65  66.0                    RCA AUTO TECH SDN BHD  ...         NaN         NaN
# 66  67.0                    Country Homesworkshop  ...         NaN         NaN
# 67  68.0                   ZAI AUTO SPEED SERVICE  ...         NaN         NaN
# 68  69.0                           AAM SPEED AUTO  ...         NaN         NaN
# 69  70.0       Pusat Service Kereta Poknik Garage  ...         NaN         NaN
#
# [70 rows x 26 columns]
